# %% [markdown]
# # Caderno 2 - Anotação usando LLMs

# %% [markdown]
# ## 1. Parâmetros

# %%
import pandas as pd
import re
import os
from openai import OpenAI
from getpass import getpass
import json

# %%
ARQUIVO_QUERY = './dados/outputs/0 - qrel - docs - query - raw_human_eval/query.csv'
ARQUIVO_QREL = './dados/outputs/0 - qrel - docs - query - raw_human_eval/qrel.csv'
ARQUIVO_DOCS = './dados/outputs/0 - qrel - docs - query - raw_human_eval/docs.csv'
ARQUIVO_HUMAN_EVALS = './dados/outputs/0 - qrel - docs - query - raw_human_eval/raw_human_eval.csv'
ARQUIVO_LLM_EVALS = './dados/outputs/2 - llm evals/raw_llm_eval.csv'

# %%
OPENAI_KEY = getpass("KEY OpenAI")
DEEPSEEK_KEY = getpass("KEY DeepSeek")
SABIA_KEY = getpass("KEY Maritaca")
GEMINI_KEY = getpass("KEY Gemini")
# Out:
# KEY OpenAI ········
# KEY DeepSeek ········
# KEY Maritaca ········
# KEY Gemini ········

# %%
client_openai = OpenAI(api_key=OPENAI_KEY)
client_deepseek = OpenAI(api_key=DEEPSEEK_KEY, base_url="https://api.deepseek.com")
client_sabia = OpenAI(api_key=SABIA_KEY, base_url="https://chat.maritaca.ai/api")
client_gemini = OpenAI(api_key=GEMINI_KEY, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# %%
CONFIGURACOES_LLM_PARA_TESTAR = [
    {
        "model": "deepseek-chat",
        "client": client_deepseek
    }
]

# %%
MSG_SISTEMA_SIMPLE_PROMPT = """
Você é um avaliador de relevância de normas do Tribunal de Contas da União (TCU).

Sua tarefa é avaliar a relevância de um DOCUMENTO em relação a uma CONSULTA (QUERY), atribuindo um score de relevância em {0, 1, 2}, conforme as regras abaixo.

### REGRAS PARA O SCORE ###:
2 – RELEVANTE: O documento responde diretamente à consulta e contém a informação central solicitada. O conteúdo é suficiente para permitir ao usuário atingir o objetivo da busca. O documento não será considerado relevante para a consulta se apenas mencionar termos semelhantes, mas não tratar efetivamente do objeto da consulta.

1 – POUCO RELEVANTE: O documento menciona o tema da consulta ou trata de assunto relacionado, mas de forma parcial ou insuficiente para atender plenamente à necessidade informacional.

0 – IRRELEVANTE: O documento não trata do assunto da consulta ou aborda tema distinto/incompatível.
### ###

A sua resposta deverá ser apenas um JSON válido, sem qualquer texto antes ou depois, e deve conter apenas o atributo "score".

### REGRAS PARA O JSON ###
"score": O valor do score (0, 1 ou 2) para o grau de relevância estimado.
### ###
""".strip()

# %%
MSG_SISTEMA_COT_PROMPT = """
Você é um avaliador de relevância de normas do Tribunal de Contas da União (TCU).

Sua tarefa é avaliar a relevância de um DOCUMENTO em relação a uma CONSULTA (QUERY), atribuindo um score de relevância em {0, 1, 2}, conforme as regras abaixo.

### REGRAS PARA O SCORE ###:
2 – RELEVANTE: O documento responde diretamente à consulta e contém a informação central solicitada. O conteúdo é suficiente para permitir ao usuário atingir o objetivo da busca. O documento não será considerado relevante para a consulta se apenas mencionar termos semelhantes, mas não tratar efetivamente do objeto da consulta.

1 – POUCO RELEVANTE: O documento menciona o tema da consulta ou trata de assunto relacionado, mas de forma parcial ou insuficiente para atender plenamente à necessidade informacional.

0 – IRRELEVANTE: O documento não trata do assunto da consulta ou aborda tema distinto/incompatível.
### ###

A sua resposta deverá ser apenas um JSON válido, sem qualquer texto antes ou depois, e deve conter apenas os atributos "justificativa" e "score", nessa ordem.

### REGRAS PARA O JSON ###
"justificativa": Texto explicando se o documento é IRRELEVANTE, POUCO RELEVANTE ou RELEVANTE para a consulta.

"score": O valor do score (0, 1 ou 2) para o grau de relevância estimado.
### ###
""".strip()

# %%
MSG_USUARIO = """
Avalie a relevância do documento para a query.

QUERY: {QUERY}

DOCUMENTO:
{DOCUMENTO}
""".strip()

# %%
PROMPTS_SISTEMA_PARA_TESTAR = {
    "simple": MSG_SISTEMA_SIMPLE_PROMPT,
    "cot": MSG_SISTEMA_COT_PROMPT
}

# %% [markdown]
# # 2. Pares únicos de QUERY_KEY/DOC_KEY para avaliar

# %%
# 1) O qrels já tem apenas pares únicos. Basta carregá-lo e filtrar as colunas QUERY_KEY e DOC_KEY
df_qrels = pd.read_csv(ARQUIVO_QREL)

pairs = df_qrels[["QUERY_KEY", "DOC_KEY"]]
pairs = list(map(tuple, pairs[["QUERY_KEY", "DOC_KEY"]].to_numpy()))

print(f'Total de pares: {len(pairs)}')
# Out:
# Total de pares: 812

# %% [markdown]
# ## 3. Funções para obter um texto a partir da QUERY_KEY e DOC_KEY

# %%
df_queries = pd.read_csv(ARQUIVO_QUERY)
df_docs = pd.read_csv(ARQUIVO_DOCS)

# %%
# função para limpar HTML com regex (sem BeautifulSoup) ---
TAG_RE = re.compile(r"<[^>]+>")
P_TAG_RE = re.compile(r"<p[^>]*>", flags=re.IGNORECASE)
def strip_html_with_paragraphs(html: str) -> str:
    if pd.isna(html):
        return ""
    # Substitui <p> e <p ...> por nova linha
    text = P_TAG_RE.sub("\n", html)
    # Remove todas as outras tags
    text = TAG_RE.sub("", text)
    # Troca nbsp por espaço vazio
    text = text.replace(' &nbsp; ', ' ')
    text = text.replace('&nbsp; ', ' ')
    text = text.replace(' &nbsp;', ' ')
    text = text.replace('&nbsp;', ' ')
    return text.strip()

# criar dicionários para acesso rápido por chave
query_text_by_key = df_queries.set_index("KEY")["TEXT"].to_dict()
def query_key_to_query(key):
    return query_text_by_key[key]

doc_html_by_key = df_docs.set_index("KEY")["TEXTONORMA"].to_dict()
def doc_key_to_doc(key):
    return strip_html_with_paragraphs(doc_html_by_key[key])

# %% [markdown]
# Testa o código para ver se é possível recuperar todas as queries e docs

# %%
for qkey, dkey in pairs:
    query_text = query_key_to_query(qkey)
    doc_text = doc_key_to_doc(dkey)

# %%
print(doc_text)
# Out:
# Constitui grupo de trabalho com objetivo de elaborar Manual de Auditoria Financeira.
#
#              O SECRETÁRIO-GERAL DE CONTROLE EXTERNO DO TRIBUNAL DE CONTAS DA UNIÃO, no uso de suas competências regulamentares e considerando o disposto no art. 33, inciso II, da Resolução-TCU n.º 253, de 21 de dezembro de 2012, resolve:
#              Art. 1º Fica constituído o Grupo de Trabalho para a elaboração de Manual de Auditoria Financeira.
#              Art. 2º O Manual de Auditoria Financeira deverá estar alinhado com as normas constitucionais e legais vigentes no Brasil, as Normas de Auditoria do TCU (NATs) e os Padrões de Auditoria Financeira, emitidos pela Organização Internacional de Entidades de Fiscalização Superior (Intosai).
#              Art. 3º O Grupo de Trabalho deverá levar em consideração também as conclusões e recomendações decorrentes das consultorias realizadas no âmbito do Projeto de Fortalecimento da Auditoria Financeira, financiado pelo Acordo de Doação TF 099104 com o Banco Mundial.
#              Art. 4º Ficam designados os auditores federais de controle externo relacionados a seguir para atuarem, sob a coordenação do primeiro, como membros do Grupo de que trata esta Portaria:
#              I – Tiago Alves de Gouveia Lins Dutra, matrícula 8172-8, Semag;
#              II - Antonio Alves de Carvalho Neto, matrícula 5657-0 , Seaud;
#              III – Diones Gomes Rocha, matrícula 5633-2, Adgecex;
#              IV – Juliane Madeira Leitão, matrícula 6539-0, Adgecex;
#              V – Lídia Firmina dos Santos, matrícula 6507-2, Semag;
#              VI - Luciana Nunes Goulart , matrícula 7681-3 , Seaud;
#              VII – Patrícia Garone Figueira Falcão, matrícula 5920-0, Semag;
#              VIII – Rodrigo Caldas Gonçalves, matrícula 3857-1, SecexFazenda;
#              IX – Pietro de Oliveira Costa, matrícula 8264-3, SecexPrevidência.
#              Parágrafo único. Os auditores não lotados na Semag atuarão sem prejuízo das respectivas atribuições, tendo em vista que atuarão somente na revisão do manual, dentro de sua área.
#              Art. 5º O Manual de Auditoria Financeira deverá ser concluído até 15 de dezembro de 2014.
#              Art. 6º O grupo proporá as auditorias piloto a serem realizadas pelas unidades da Segecex até 10 de fevereiro de 2014 para sua programação.
#              Art. 7º Esta Portaria entra em vigor na data de sua publicação.
#
#
# (assinado eletronicamente)
#
# MAURÍCIO DE ALBUQUERQUE WANDERLEY

# %% [markdown]
# ## 4. Anotação usando LLM

# %% [markdown]
# ### 4.1. Carrega/cria o arquivo onde ficarão as avaliações

# %%
# Verifica se o arquivo existe
if os.path.exists(ARQUIVO_LLM_EVALS):
    df_llm_evals = pd.read_csv(ARQUIVO_LLM_EVALS)
else:
    # Cria o DataFrame com a estrutura desejada
    df_llm_evals = pd.DataFrame(columns=[
        'QUERY_KEY', 'DOC_KEY', 'AVALIACAO', 'MODELO', 'PROMPT', 'PAYLOAD_LLM'
    ])
    
    # Salva o novo DataFrame no arquivo
    df_llm_evals.to_csv(ARQUIVO_LLM_EVALS, index=False)

# %% [markdown]
# ### 4.2. Função genérica para avaliar um par de query-documento usando algum modelo/prompt

# %%
def extract_token_limits_from_exception(llm_model, exc: Exception):
    error_text = str(exc)

    if llm_model == 'deepseek-chat':
        pattern = r'maximum context length is (\d+) tokens.*requested (\d+) tokens'
        match = re.search(pattern, error_text)

        if not match:
            return None

        max_context = int(match.group(1))
        requested = int(match.group(2))

        return max_context, requested

# %%
def avaliar(query_key, doc_key, llm_model, msg_sistema, client, perc_max_texto=1.0):
    query_text = query_key_to_query(query_key)
    doc_text = doc_key_to_doc(doc_key)

    idx_truncamento = int(len(doc_text) * perc_max_texto)
    doc_text_truncado = doc_text[:idx_truncamento]
    
    try:
        response = client.chat.completions.create(
            model=llm_model,
            messages=[
                {"role": "system", "content": msg_sistema},
                {"role": "user", "content": MSG_USUARIO.format(QUERY=query_text, DOCUMENTO=doc_text_truncado)}
            ],
            temperature=0,
            stream=False
        )
        content = response.choices[0].message.content
    except Exception as e:
        result = extract_token_limits_from_exception(llm_model, e)
        
        if result is None:
            print(e)
        else:
            contexto_max, contexto_pedido = result
            percentual_truncar = 0.95 * perc_max_texto * contexto_max/contexto_pedido
            print(f'{query_key}/{doc_key}. Solicitado {contexto_pedido} tokens, mas modelo suporta {contexto_max}. Tenta novamente truncando com fator {percentual_truncar}')
            return avaliar(query_key, doc_key, llm_model, msg_sistema, client, percentual_truncar)

    # Pode ser que o LLM responda com algo diferente do json. Nesse caso, seta o score para -1 e salva para reavaliarmos novamente depois
    try:
        # Sanitiza content. As vezes retorna iniciando e terminando com sinalizadores de json
        content = content.replace('```json', '').replace('```', '')
        score = json.loads(content)['score']
    except Exception as e:
        score = -1

    return score, content

# %% [markdown]
# ### 4.4. Loop para avaliação em todos os modelos/prompts/pares de documentos-query

# %%
for qkey, dkey in pairs:
    for nome_prompt, prompt_sistema in PROMPTS_SISTEMA_PARA_TESTAR.items():
        for config_llm in CONFIGURACOES_LLM_PARA_TESTAR:
            model = config_llm['model']
            client = config_llm['client']
        
            # Verifica se já existe essa combinação no df_llm_evals
            ja_foi_avaliado = (
                (df_llm_evals['QUERY_KEY'] == qkey) &
                (df_llm_evals['DOC_KEY'] == dkey) &
                (df_llm_evals['MODELO'] == model) &
                (df_llm_evals['PROMPT'] == nome_prompt)
            )

            if ja_foi_avaliado.any():
                # Esse modelo já tem avaliação, passa para o próximo
                score_do_modelo = df_llm_evals.loc[ja_foi_avaliado, 'AVALIACAO'].values[0]
                print(f'Já possui avaliação para {qkey}/{dkey}/{model}/{nome_prompt}: {score_do_modelo}')
                continue

            # Se não foi avaliado, avalia e extrai score e payload
            score, payload = avaliar(qkey, dkey, model, prompt_sistema, client)
            print(f'Avaliando para {qkey}/{dkey}/{model}/{nome_prompt}: {score}')

            # Cria a nova avaliação
            nova_avaliacao = {
                'QUERY_KEY': qkey,
                'DOC_KEY': dkey,
                'AVALIACAO': score,
                'MODELO': model,
                'PROMPT': nome_prompt,
                'PAYLOAD_LLM': payload
            }

            # Adiciona ao DataFrame
            df_llm_evals = pd.concat([df_llm_evals, pd.DataFrame([nova_avaliacao])], ignore_index=True)
    
            # Salva no arquivo
            df_llm_evals.to_csv(ARQUIVO_LLM_EVALS, index=False)
# Out:
# Já possui avaliação para 1/NORMA-21217/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-21217/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-19574/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-19574/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-21779/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-21779/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21754/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-21754/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-21621/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-21621/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-21432/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-21432/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-23521/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-23521/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21650/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21650/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21630/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-21630/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-15237/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-15237/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-19602/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-19602/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-9382/deepseek-chat/simple: 2
# Já possui avaliação para 1/NORMA-9382/deepseek-chat/cot: 2
# Já possui avaliação para 1/NORMA-19640/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-19640/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21727/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21727/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-21661/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21661/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-21506/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21506/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21484/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-21484/deepseek-chat/cot: 1
# Já possui avaliação para 1/NORMA-21439/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21439/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-21258/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-21258/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-21249/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-21249/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-19629/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-19629/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-19624/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-19624/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-19597/deepseek-chat/simple: 1
# Já possui avaliação para 1/NORMA-19597/deepseek-chat/cot: 0
# Já possui avaliação para 1/NORMA-2603/deepseek-chat/simple: 0
# Já possui avaliação para 1/NORMA-2603/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-21700/deepseek-chat/simple: 1
# Já possui avaliação para 2/NORMA-21700/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-21638/deepseek-chat/simple: 2
# Já possui avaliação para 2/NORMA-21638/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-14390/deepseek-chat/simple: 2
# Já possui avaliação para 2/NORMA-14390/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-20790/deepseek-chat/simple: 2
# Já possui avaliação para 2/NORMA-20790/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-20139/deepseek-chat/simple: 1
# Já possui avaliação para 2/NORMA-20139/deepseek-chat/cot: 1
# Já possui avaliação para 2/NORMA-6176/deepseek-chat/simple: 2
# Já possui avaliação para 2/NORMA-6176/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-21709/deepseek-chat/simple: 1
# Já possui avaliação para 2/NORMA-21709/deepseek-chat/cot: 1
# Já possui avaliação para 2/NORMA-21478/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-21478/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-21711/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-21711/deepseek-chat/cot: 1
# Já possui avaliação para 2/NORMA-21509/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-21509/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-20761/deepseek-chat/simple: 2
# Já possui avaliação para 2/NORMA-20761/deepseek-chat/cot: 2
# Já possui avaliação para 2/NORMA-18530/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-18530/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-21790/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-21790/deepseek-chat/cot: 1
# Já possui avaliação para 2/NORMA-21536/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-21536/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-19429/deepseek-chat/simple: 1
# Já possui avaliação para 2/NORMA-19429/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-18999/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-18999/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-18962/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-18962/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-18533/deepseek-chat/simple: 0
# Já possui avaliação para 2/NORMA-18533/deepseek-chat/cot: 0
# Já possui avaliação para 2/NORMA-1620/deepseek-chat/simple: 1
# Já possui avaliação para 2/NORMA-1620/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-26124/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-26124/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-22101/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-22101/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21650/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-21650/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21597/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-21597/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-21508/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-21508/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21466/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-21466/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-21456/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-21456/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21446/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-21446/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21407/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-21407/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-21261/deepseek-chat/simple: 0
# Já possui avaliação para 3/NORMA-21261/deepseek-chat/cot: 0
# Já possui avaliação para 3/NORMA-21245/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-21245/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-19596/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-19596/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-19614/deepseek-chat/simple: 0
# Já possui avaliação para 3/NORMA-19614/deepseek-chat/cot: 0
# Já possui avaliação para 3/NORMA-21394/deepseek-chat/simple: 0
# Já possui avaliação para 3/NORMA-21394/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-19651/deepseek-chat/simple: 2
# Já possui avaliação para 3/NORMA-19651/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-21219/deepseek-chat/simple: 0
# Já possui avaliação para 3/NORMA-21219/deepseek-chat/cot: 1
# Já possui avaliação para 3/NORMA-21249/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-21249/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-19640/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-19640/deepseek-chat/cot: 2
# Já possui avaliação para 3/NORMA-19816/deepseek-chat/simple: 0
# Já possui avaliação para 3/NORMA-19816/deepseek-chat/cot: 0
# Já possui avaliação para 3/NORMA-19628/deepseek-chat/simple: 1
# Já possui avaliação para 3/NORMA-19628/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-20223/deepseek-chat/simple: 1
# Já possui avaliação para 4/NORMA-20223/deepseek-chat/cot: 2
# Já possui avaliação para 4/NORMA-19629/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-19629/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-8028/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-8028/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-27365/deepseek-chat/simple: 1
# Já possui avaliação para 4/NORMA-27365/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-27364/deepseek-chat/simple: 1
# Já possui avaliação para 4/NORMA-27364/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-26201/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-26201/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-22721/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-22721/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-21718/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-21718/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-21539/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-21539/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-21437/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-21437/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-20794/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-20794/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-20430/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-20430/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-20427/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-20427/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-20137/deepseek-chat/simple: 1
# Já possui avaliação para 4/NORMA-20137/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-15229/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-15229/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-14967/deepseek-chat/simple: 1
# Já possui avaliação para 4/NORMA-14967/deepseek-chat/cot: 2
# Já possui avaliação para 4/NORMA-14688/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-14688/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-6881/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-6881/deepseek-chat/cot: 1
# Já possui avaliação para 4/NORMA-6826/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-6826/deepseek-chat/cot: 0
# Já possui avaliação para 4/NORMA-2603/deepseek-chat/simple: 0
# Já possui avaliação para 4/NORMA-2603/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-24961/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-24961/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-21369/deepseek-chat/simple: 2
# Já possui avaliação para 5/NORMA-21369/deepseek-chat/cot: 2
# Já possui avaliação para 5/NORMA-21608/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-21608/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-19295/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-19295/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-21606/deepseek-chat/simple: 1
# Já possui avaliação para 5/NORMA-21606/deepseek-chat/cot: 1
# Já possui avaliação para 5/NORMA-21651/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-21651/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-18270/deepseek-chat/simple: 1
# Já possui avaliação para 5/NORMA-18270/deepseek-chat/cot: 1
# Já possui avaliação para 5/NORMA-12954/deepseek-chat/simple: 1
# Já possui avaliação para 5/NORMA-12954/deepseek-chat/cot: 1
# Já possui avaliação para 5/NORMA-22861/deepseek-chat/simple: 1
# Já possui avaliação para 5/NORMA-22861/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-21742/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-21742/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-10749/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-10749/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-25902/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-25902/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-25082/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-25082/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-21547/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-21547/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-20240/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-20240/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-15249/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-15249/deepseek-chat/cot: 0
# Já possui avaliação para 5/NORMA-14749/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-14749/deepseek-chat/cot: 1
# Já possui avaliação para 5/NORMA-14504/deepseek-chat/simple: 0
# Já possui avaliação para 5/NORMA-14504/deepseek-chat/cot: 1
# Já possui avaliação para 6/NORMA-20223/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-20223/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-19629/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-19629/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-8028/deepseek-chat/simple: 1
# Já possui avaliação para 6/NORMA-8028/deepseek-chat/cot: 1
# Já possui avaliação para 6/NORMA-27365/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-27365/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-27364/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-27364/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-15229/deepseek-chat/simple: 1
# Já possui avaliação para 6/NORMA-15229/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-14688/deepseek-chat/simple: 1
# Já possui avaliação para 6/NORMA-14688/deepseek-chat/cot: 1
# Já possui avaliação para 6/NORMA-6881/deepseek-chat/simple: 1
# Já possui avaliação para 6/NORMA-6881/deepseek-chat/cot: 1
# Já possui avaliação para 6/NORMA-26201/deepseek-chat/simple: 1
# Já possui avaliação para 6/NORMA-26201/deepseek-chat/cot: 1
# Já possui avaliação para 6/NORMA-22721/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-22721/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-21718/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-21718/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-21539/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-21539/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-21437/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-21437/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-20794/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-20794/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-20430/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-20430/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-20427/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-20427/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-20137/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-20137/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-14967/deepseek-chat/simple: 2
# Já possui avaliação para 6/NORMA-14967/deepseek-chat/cot: 2
# Já possui avaliação para 6/NORMA-6826/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-6826/deepseek-chat/cot: 0
# Já possui avaliação para 6/NORMA-2603/deepseek-chat/simple: 0
# Já possui avaliação para 6/NORMA-2603/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21402/deepseek-chat/simple: 2
# Já possui avaliação para 7/NORMA-21402/deepseek-chat/cot: 2
# Já possui avaliação para 7/NORMA-21703/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-21703/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21280/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-21280/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-19000/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-19000/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-18996/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-18996/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-18754/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-18754/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-18994/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-18994/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-20129/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-20129/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21711/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21711/deepseek-chat/cot: 2
# Já possui avaliação para 7/NORMA-19514/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-19514/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-18756/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-18756/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-21761/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21761/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21709/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-21709/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21701/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21701/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21635/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21635/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-21536/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21536/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-21509/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-21509/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-21423/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-21423/deepseek-chat/cot: 1
# Já possui avaliação para 7/NORMA-19374/deepseek-chat/simple: 1
# Já possui avaliação para 7/NORMA-19374/deepseek-chat/cot: 0
# Já possui avaliação para 7/NORMA-19267/deepseek-chat/simple: 0
# Já possui avaliação para 7/NORMA-19267/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-27101/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-27101/deepseek-chat/cot: 0
# Já possui avaliação para 8/NORMA-21705/deepseek-chat/simple: 2
# Já possui avaliação para 8/NORMA-21705/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-21437/deepseek-chat/simple: 2
# Já possui avaliação para 8/NORMA-21437/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-20397/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-20397/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-20989/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-20989/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-18430/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-18430/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-21537/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-21537/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-21524/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-21524/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-21523/deepseek-chat/simple: 2
# Já possui avaliação para 8/NORMA-21523/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-21272/deepseek-chat/simple: 2
# Já possui avaliação para 8/NORMA-21272/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-20189/deepseek-chat/simple: 2
# Já possui avaliação para 8/NORMA-20189/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-7110/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-7110/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-18958/deepseek-chat/simple: 1
# Já possui avaliação para 8/NORMA-18958/deepseek-chat/cot: 2
# Já possui avaliação para 8/NORMA-24961/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-24961/deepseek-chat/cot: 0
# Já possui avaliação para 8/NORMA-818/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-818/deepseek-chat/cot: 0
# Já possui avaliação para 8/NORMA-25542/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-25542/deepseek-chat/cot: 0
# Já possui avaliação para 8/NORMA-21586/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-21586/deepseek-chat/cot: 0
# Já possui avaliação para 8/NORMA-21444/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-21444/deepseek-chat/cot: 1
# Já possui avaliação para 8/NORMA-21369/deepseek-chat/simple: 0
# Já possui avaliação para 8/NORMA-21369/deepseek-chat/cot: 1
# Já possui avaliação para 9/NORMA-20302/deepseek-chat/simple: 2
# Já possui avaliação para 9/NORMA-20302/deepseek-chat/cot: 2
# Já possui avaliação para 9/NORMA-25101/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-25101/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-5913/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-5913/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-9959/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-9959/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-27364/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-27364/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-18748/deepseek-chat/simple: 1
# Já possui avaliação para 9/NORMA-18748/deepseek-chat/cot: 1
# Já possui avaliação para 9/NORMA-13789/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-13789/deepseek-chat/cot: 1
# Já possui avaliação para 9/NORMA-12733/deepseek-chat/simple: 1
# Já possui avaliação para 9/NORMA-12733/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-3966/deepseek-chat/simple: 2
# Já possui avaliação para 9/NORMA-3966/deepseek-chat/cot: 1
# Já possui avaliação para 9/NORMA-21762/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-21762/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-19123/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-19123/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-13746/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-13746/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-25082/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-25082/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-22661/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-22661/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-15253/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-15253/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-14055/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-14055/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-13308/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-13308/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-11904/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-11904/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-9960/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-9960/deepseek-chat/cot: 0
# Já possui avaliação para 9/NORMA-6332/deepseek-chat/simple: 0
# Já possui avaliação para 9/NORMA-6332/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-21638/deepseek-chat/simple: 2
# Já possui avaliação para 10/NORMA-21638/deepseek-chat/cot: 2
# Já possui avaliação para 10/NORMA-23361/deepseek-chat/simple: 2
# Já possui avaliação para 10/NORMA-23361/deepseek-chat/cot: 2
# Já possui avaliação para 10/NORMA-21706/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-21706/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-21700/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-21700/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-21649/deepseek-chat/simple: 2
# Já possui avaliação para 10/NORMA-21649/deepseek-chat/cot: 2
# Já possui avaliação para 10/NORMA-13848/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-13848/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-22862/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-22862/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-21703/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-21703/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-16424/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-16424/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-13610/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-13610/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-6176/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-6176/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-20790/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-20790/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-21478/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-21478/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-13795/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-13795/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-21709/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-21709/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-21475/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-21475/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-19467/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-19467/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-21711/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-21711/deepseek-chat/cot: 1
# Já possui avaliação para 10/NORMA-20777/deepseek-chat/simple: 0
# Já possui avaliação para 10/NORMA-20777/deepseek-chat/cot: 0
# Já possui avaliação para 10/NORMA-27221/deepseek-chat/simple: 1
# Já possui avaliação para 10/NORMA-27221/deepseek-chat/cot: 1
# Já possui avaliação para 11/NORMA-20205/deepseek-chat/simple: 1
# Já possui avaliação para 11/NORMA-20205/deepseek-chat/cot: 1
# Já possui avaliação para 11/NORMA-18654/deepseek-chat/simple: 0
# 11/NORMA-18654. Solicitado 173183 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.7189989779597304
# Avaliando para 11/NORMA-18654/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-27101/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-27101/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-24961/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-24961/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-27501/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-27501/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-25902/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-25902/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-2649/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-2649/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-2603/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-2603/deepseek-chat/cot: 0
# Avaliando para 11/NORMA-962/deepseek-chat/simple: 0
# Avaliando para 11/NORMA-962/deepseek-chat/cot: 0
# Avaliando para 13/NORMA-19105/deepseek-chat/simple: 2
# Avaliando para 13/NORMA-19105/deepseek-chat/cot: 2
# Avaliando para 13/NORMA-20201/deepseek-chat/simple: 2
# Avaliando para 13/NORMA-20201/deepseek-chat/cot: 2
# Avaliando para 13/NORMA-20199/deepseek-chat/simple: 2
# Avaliando para 13/NORMA-20199/deepseek-chat/cot: 2
# Avaliando para 13/NORMA-21729/deepseek-chat/simple: 2
# Avaliando para 13/NORMA-21729/deepseek-chat/cot: 2
# Avaliando para 13/NORMA-9724/deepseek-chat/simple: 2
# Avaliando para 13/NORMA-9724/deepseek-chat/cot: 2
# Avaliando para 13/NORMA-7386/deepseek-chat/simple: 1
deepseek-chat/simple: 0
# Avaliando para 21/NORMA-21631/deepseek-chat/cot: 0
# Avaliando para 21/NORMA-26841/deepseek-chat/simple: 0
# Avaliando para 21/NORMA-26841/deepseek-chat/cot: 0
# Avaliando para 21/NORMA-22561/deepseek-chat/simple: 1
# Avaliando para 21/NORMA-22561/deepseek-chat/cot: 1
# Avaliando para 21/NORMA-21767/deepseek-chat/simple: 0
# Avaliando para 21/NORMA-21767/deepseek-chat/cot: 0
# Avaliando para 21/NORMA-19684/deepseek-chat/simple: 0
# Avaliando para 21/NORMA-19684/deepseek-chat/cot: 0
# Avaliando para 21/NORMA-19565/deepseek-chat/simple: 0
# Avaliando para 21/NORMA-19565/deepseek-chat/cot: 0
# Avaliando para 21/NORMA-19128/deepseek-chat/simple: 0
# Avaliando para 21/NORMA-19128/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-21268/deepseek-chat/simple: 2
# Avaliando para 23/NORMA-21268/deepseek-chat/cot: 2
# Avaliando para 23/NORMA-20796/deepseek-chat/simple: 2
# Avaliando para 23/NORMA-20796/deepseek-chat/cot: 2
# Avaliando para 23/NORMA-20837/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20837/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20193/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20193/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20187/deepseek-chat/simple: 1
# Avaliando para 23/NORMA-20187/deepseek-chat/cot: 1
# Avaliando para 23/NORMA-18788/deepseek-chat/simple: 1
# Avaliando para 23/NORMA-18788/deepseek-chat/cot: 2
# Avaliando para 23/NORMA-2120/deepseek-chat/simple: 1
# Avaliando para 23/NORMA-2120/deepseek-chat/cot: 1
# Avaliando para 23/NORMA-26102/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-26102/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-24961/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-24961/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-21784/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-21784/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-21729/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-21729/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20869/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20869/deepseek-chat/cot: 0
# 23/NORMA-20367. Solicitado 305918 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.4070319497381651
# Avaliando para 23/NORMA-20367/deepseek-chat/simple: 0
# 23/NORMA-20367. Solicitado 305967 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.4069667643896237
# Avaliando para 23/NORMA-20367/deepseek-chat/cot: 0
# 23/NORMA-20365. Solicitado 157001 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.7931057763963286
# Avaliando para 23/NORMA-20365/deepseek-chat/simple: 0
# 23/NORMA-20365. Solicitado 157050 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.7928583253740846
# Avaliando para 23/NORMA-20365/deepseek-chat/cot: 0
# 23/NORMA-20324. Solicitado 305341 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.407801114164164
# Avaliando para 23/NORMA-20324/deepseek-chat/simple: 0
# 23/NORMA-20324. Solicitado 305390 tokens, mas modelo suporta 131072. Tenta novamente truncando com fator 0.4077356822423786
# Avaliando para 23/NORMA-20324/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20205/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20205/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20204/deepseek-chat/simple: 1
# Avaliando para 23/NORMA-20204/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20202/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20202/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-20198/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-20198/deepseek-chat/cot: 0
# Avaliando para 23/NORMA-18818/deepseek-chat/simple: 0
# Avaliando para 23/NORMA-18818/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-76/deepseek-chat/simple: 2
# Avaliando para 24/NORMA-76/deepseek-chat/cot: 2
# Avaliando para 24/NORMA-18394/deepseek-chat/simple: 1
# Avaliando para 24/NORMA-18394/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-21626/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-21626/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-2537/deepseek-chat/simple: 1
# Avaliando para 24/NORMA-2537/deepseek-chat/cot: 1
# Avaliando para 24/NORMA-751/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-751/deepseek-chat/cot: 1
# Avaliando para 24/NORMA-736/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-736/deepseek-chat/cot: 1
# Avaliando para 24/NORMA-20869/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-20869/deepseek-chat/cot: 1
# Avaliando para 24/NORMA-850/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-850/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-25964/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-25964/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-23441/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-23441/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-21739/deepseek-chat/simple: 1
# Avaliando para 24/NORMA-21739/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-21308/deepseek-chat/simple: 1
# Avaliando para 24/NORMA-21308/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-2395/deepseek-chat/simple: 0
# Avaliando para 24/NORMA-2395/deepseek-chat/cot: 0
# Avaliando para 24/NORMA-1674/deepseek-chat/simple: 1
# Avaliando para 24/NORMA-1674/deepseek-chat/cot: 0
# Avaliando para 25/NORMA-1674/deepseek-chat/simple: 2
# Avaliando para 25/NORMA-1674/deepseek-chat/cot: 2
# Avaliando para 25/NORMA-1129/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-1129/deepseek-chat/cot: 2
# Avaliando para 25/NORMA-21626/deepseek-chat/simple: 2
# Avaliando para 25/NORMA-21626/deepseek-chat/cot: 2
# Avaliando para 25/NORMA-21308/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-21308/deepseek-chat/cot: 2
# Avaliando para 25/NORMA-1776/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-1776/deepseek-chat/cot: 1
# Avaliando para 25/NORMA-21712/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-21712/deepseek-chat/cot: 1
# Avaliando para 25/NORMA-1334/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-1334/deepseek-chat/cot: 1
# Avaliando para 25/NORMA-21739/deepseek-chat/simple: 2
# Avaliando para 25/NORMA-21739/deepseek-chat/cot: 2
# Avaliando para 25/NORMA-850/deepseek-chat/simple: 1
# Avaliando para 25/NORMA-850/deepseek-chat/cot: 0
# Avaliando para 25/NORMA-25523/deepseek-chat/simple: 0
# Avaliando para 25/NORMA-25523/deepseek-chat/cot: 0
# Avaliando para 25/NORMA-22941/deepseek-chat/simple: 0
# Avaliando para 25/NORMA-22941/deepseek-chat/cot: 1
# Avaliando para 25/NORMA-21756/deepseek-chat/simple: 0
# Avaliando para 25/NORMA-21756/deepseek-chat/cot: 0
# ...
# Avaliando para 42/NORMA-18999/deepseek-chat/simple: 1
# Avaliando para 42/NORMA-18999/deepseek-chat/cot: 0
# Avaliando para 42/NORMA-18748/deepseek-chat/simple: 1
# Avaliando para 42/NORMA-18748/deepseek-chat/cot: 2
# Avaliando para 42/NORMA-21601/deepseek-chat/simple: 1
# Avaliando para 42/NORMA-21601/deepseek-chat/cot: 2
# Avaliando para 42/NORMA-21586/deepseek-chat/simple: 1
# Avaliando para 42/NORMA-21586/deepseek-chat/cot: 1
# Avaliando para 42/NORMA-21534/deepseek-chat/simple: 2
# Avaliando para 42/NORMA-21534/deepseek-chat/cot: 2
# Avaliando para 42/NORMA-21353/deepseek-chat/simple: 2
# Avaliando para 42/NORMA-21353/deepseek-chat/cot: 2
# Avaliando para 42/NORMA-19272/deepseek-chat/simple: 1
# Avaliando para 42/NORMA-19272/deepseek-chat/cot: 1
# Avaliando para 42/NORMA-21576/deepseek-chat/simple: 2
# Avaliando para 42/NORMA-21576/deepseek-chat/cot: 2
# Avaliando para 42/NORMA-21448/deepseek-chat/simple: 2
# Avaliando para 42/NORMA-21448/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-21690/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-21690/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-19780/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-19780/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-19565/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-19565/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-20134/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-20134/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-19518/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-19518/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-27761/deepseek-chat/simple: 1
# Avaliando para 43/NORMA-27761/deepseek-chat/cot: 1
# Avaliando para 43/NORMA-19729/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-19729/deepseek-chat/cot: 1
# Avaliando para 43/NORMA-21471/deepseek-chat/simple: 0
# Avaliando para 43/NORMA-21471/deepseek-chat/cot: 0
# Avaliando para 43/NORMA-21367/deepseek-chat/simple: 0
# Avaliando para 43/NORMA-21367/deepseek-chat/cot: 0
# Avaliando para 43/NORMA-21150/deepseek-chat/simple: 0
# Avaliando para 43/NORMA-21150/deepseek-chat/cot: 0
# Avaliando para 43/NORMA-21121/deepseek-chat/simple: 1
# Avaliando para 43/NORMA-21121/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-21058/deepseek-chat/simple: 2
# Avaliando para 43/NORMA-21058/deepseek-chat/cot: 2
# Avaliando para 43/NORMA-20283/deepseek-chat/simple: 0
# Avaliando para 44/NORMA-20302/deepseek-chat/cot: 0
# Avaliando para 44/NORMA-20217/deepseek-chat/simple: 0
# Avaliando para 44/NORMA-20217/deepseek-chat/cot: 0
# Avaliando para 44/NORMA-20212/deepseek-chat/simple: 0
# Avaliando para 44/NORMA-20212/deepseek-chat/cot: 1
# Avaliando para 44/NORMA-18214/deepseek-chat/simple: 0
# Avaliando para 44/NORMA-18214/deepseek-chat/cot: 0
# Avaliando para 45/NORMA-21279/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-21279/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-25682/deepseek-chat/simple: 0
# Avaliando para 45/NORMA-25682/deepseek-chat/cot: 0
# Avaliando para 45/NORMA-25621/deepseek-chat/simple: 0
# Avaliando para 45/NORMA-25621/deepseek-chat/cot: 0
# Avaliando para 45/NORMA-21773/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-21773/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-21623/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-21623/deepseek-chat/cot: 0
# Avaliando para 45/NORMA-21616/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-21616/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-21477/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-21477/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-21342/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-21342/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-19535/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-19535/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-19309/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-19309/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-20267/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-20267/deepseek-chat/cot: 0
# Avaliando para 45/NORMA-14786/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-14786/deepseek-chat/cot: 1
# Avaliando para 45/NORMA-12495/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-12495/deepseek-chat/cot: 1
# Avaliando para 45/NORMA-19435/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-19435/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-27761/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-27761/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-27022/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-27022/deepseek-chat/cot: 1
# Avaliando para 45/NORMA-16202/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-16202/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-19306/deepseek-chat/simple: 1
# Avaliando para 45/NORMA-19306/deepseek-chat/cot: 2
# Avaliando para 45/NORMA-19237/deepseek-chat/simple: 2
# Avaliando para 45/NORMA-19237/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-21406/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-21406/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-14395/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-14395/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-14516/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-14516/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-3121/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-3121/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-1662/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-1662/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-2137/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-2137/deepseek-chat/cot: 1
# Avaliando para 46/NORMA-2135/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-2135/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-1681/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-1681/deepseek-chat/cot: 1
# Avaliando para 46/NORMA-323/deepseek-chat/simple: 2
# Avaliando para 46/NORMA-323/deepseek-chat/cot: 2
# Avaliando para 46/NORMA-1714/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-1714/deepseek-chat/cot: 1
# Avaliando para 46/NORMA-1727/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-1727/deepseek-chat/cot: 1
# Avaliando para 46/NORMA-6711/deepseek-chat/simple: 0
# Avaliando para 46/NORMA-6711/deepseek-chat/cot: 0
# Avaliando para 46/NORMA-23965/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-23965/deepseek-chat/cot: 0
# Avaliando para 46/NORMA-17801/deepseek-chat/simple: 0
# Avaliando para 46/NORMA-17801/deepseek-chat/cot: 0
# Avaliando para 46/NORMA-16442/deepseek-chat/simple: 1
# Avaliando para 46/NORMA-16442/deepseek-chat/cot: 0
# Avaliando para 46/NORMA-5077/deepseek-chat/simple: 0
# Avaliando para 46/NORMA-5077/deepseek-chat/cot: 0
# Avaliando para 47/NORMA-28181/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-28181/deepseek-chat/cot: 2
# Avaliando para 47/NORMA-2069/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-2069/deepseek-chat/cot: 2
# Avaliando para 47/NORMA-15603/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-15603/deepseek-chat/cot: 2
# Avaliando para 47/NORMA-3201/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-3201/deepseek-chat/cot: 2
# Avaliando para 47/NORMA-3342/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-3342/deepseek-chat/cot: 2
# Avaliando para 47/NORMA-2563/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-2563/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-1945/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-1945/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-27761/deepseek-chat/simple: 0
# Avaliando para 47/NORMA-27761/deepseek-chat/cot: 0
# Avaliando para 47/NORMA-25981/deepseek-chat/simple: 0
# Avaliando para 47/NORMA-25981/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-17321/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-17321/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-13160/deepseek-chat/simple: 0
# Avaliando para 47/NORMA-13160/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-2589/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-2589/deepseek-chat/cot: 0
# Avaliando para 47/NORMA-2531/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-2531/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-2503/deepseek-chat/simple: 2
# Avaliando para 47/NORMA-2503/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-2428/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-2428/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-1851/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-1851/deepseek-chat/cot: 1
# Avaliando para 47/NORMA-1662/deepseek-chat/simple: 0
# Avaliando para 47/NORMA-1662/deepseek-chat/cot: 0
# Avaliando para 47/NORMA-1334/deepseek-chat/simple: 0
# Avaliando para 47/NORMA-1334/deepseek-chat/cot: 0
# Avaliando para 47/NORMA-972/deepseek-chat/simple: 1
# Avaliando para 47/NORMA-972/deepseek-chat/cot: 0
# Avaliando para 48/NORMA-23222/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-23222/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-21744/deepseek-chat/simple: 1
# Avaliando para 48/NORMA-21744/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-21721/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-21721/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-19786/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-19786/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-13545/deepseek-chat/simple: 1
# Avaliando para 48/NORMA-13545/deepseek-chat/cot: 1
# Avaliando para 48/NORMA-21648/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-21648/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-21450/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-21450/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-20140/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-20140/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-11454/deepseek-chat/simple: 1
# Avaliando para 48/NORMA-11454/deepseek-chat/cot: 1
# Avaliando para 48/NORMA-21261/deepseek-chat/simple: 1
# Avaliando para 48/NORMA-21261/deepseek-chat/cot: 1
# Avaliando para 48/NORMA-21470/deepseek-chat/simple: 1
# Avaliando para 48/NORMA-21470/deepseek-chat/cot: 1
# Avaliando para 48/NORMA-12872/deepseek-chat/simple: 2
# Avaliando para 48/NORMA-12872/deepseek-chat/cot: 2
# Avaliando para 48/NORMA-11758/deepseek-chat/simple: 0
# Avaliando para 48/NORMA-11758/deepseek-chat/cot: 0
# Avaliando para 49/NORMA-2144/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-2144/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-17221/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-17221/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-1674/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1674/deepseek-chat/cot: 2
# Avaliando para 49/NORMA-1334/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1334/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-875/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-875/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-1863/deepseek-chat/simple: 2
# Avaliando para 49/NORMA-1863/deepseek-chat/cot: 2
# Avaliando para 49/NORMA-2496/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-2496/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-2383/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-2383/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-1408/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1408/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-1398/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1398/deepseek-chat/cot: 2
# Avaliando para 49/NORMA-1390/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1390/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-1332/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-1332/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-751/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-751/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-736/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-736/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-680/deepseek-chat/simple: 0
# Avaliando para 49/NORMA-680/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-2558/deepseek-chat/simple: 0
# Avaliando para 49/NORMA-2558/deepseek-chat/cot: 1
# Avaliando para 49/NORMA-15603/deepseek-chat/simple: 0
# Avaliando para 49/NORMA-15603/deepseek-chat/cot: 0
# Avaliando para 49/NORMA-2395/deepseek-chat/simple: 1
# Avaliando para 49/NORMA-2395/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-21267/deepseek-chat/simple: 2
# Avaliando para 50/NORMA-21267/deepseek-chat/cot: 2
# Avaliando para 50/NORMA-11316/deepseek-chat/simple: 2
# Avaliando para 50/NORMA-11316/deepseek-chat/cot: 2
# Avaliando para 50/NORMA-818/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-818/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-1188/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-1188/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-13138/deepseek-chat/simple: 2
# Avaliando para 50/NORMA-13138/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-13004/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-13004/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-21739/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-21739/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-24582/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-24582/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-1346/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-1346/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-24661/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-24661/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-22941/deepseek-chat/simple: 1
# Avaliando para 50/NORMA-22941/deepseek-chat/cot: 1
# Avaliando para 50/NORMA-2531/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-2531/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-1334/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-1334/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-972/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-972/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-24041/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-24041/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-2503/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-2503/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-2483/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-2483/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-2478/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-2478/deepseek-chat/cot: 0
# Avaliando para 50/NORMA-2395/deepseek-chat/simple: 0
# Avaliando para 50/NORMA-2395/deepseek-chat/cot: 0
