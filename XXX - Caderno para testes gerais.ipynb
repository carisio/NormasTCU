# %%
import pandas as pd
from metricas import metricas

# DataFrame qrels
qrels = pd.DataFrame({
    "QUERY_KEY": ["Q1", "Q1"],
    "DOC_KEY": ["D1", "D2"],
    "SCORE": [2, 2]
})

# DataFrame run
run = pd.DataFrame({
    "QUERY_KEY": ["Q1", "Q1", "Q1", "Q1"],
    "DOC_KEY": ["D1", "D2", "D3", "D4"],
    "RANK": [4, 3, 2, 1]
})

metricas(run, qrels, k=[1, 2, 3])
# Out:
#   QUERY_KEY  P@1  P@2       P@3  R@1  R@2  R@3  nDCG@1  nDCG@2    nDCG@3  \
# 0        Q1  0.0  0.0  0.333333  0.0  0.0  0.5     0.0     0.0  0.306574
#
#         MRR
# 0  0.333333
